# %% [markdown]
# # Emotion Detection

# %% [markdown]
# ## Importing Liabraries

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensorflow version: 2.15.0

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(8,8))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing data for training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator  = datagen_train.flow_from_directory("train/", 
                                                     target_size = (img_size, img_size),
                                                     color_mode = "grayscale",
                                                     batch_size = batch_size,
                                                     class_mode = "categorical",
                                                     shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size, img_size),
                                                     color_mode = "grayscale",
                                                     batch_size = batch_size,
                                                     class_mode = "categorical",
                                                     shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs, 32,(3,3))
    conv_2 = Convolution(inputs, 64,(5,5))
    conv_3 = Convolution(inputs, 128,(3,3))
    
    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten, 256)
    
    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor = "val_accuracy", save_weights_only = True, mode = 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# ## Training the model

# %% [markdown]
#  **The next cell takes time to complete**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs, 
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Mayur\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6437 - accuracy: 0.3782
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 430s 949ms/step - loss: 1.6437 - accuracy: 0.3782 - val_loss: 1.9526 - val_accuracy: 0.2741
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3488 - accuracy: 0.4857
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 436s 973ms/step - loss: 1.3488 - accuracy: 0.4857 - val_loss: 1.4639 - val_accuracy: 0.4386
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1895 - accuracy: 0.5580
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 427s 952ms/step - loss: 1.1895 - accuracy: 0.5580 - val_loss: 1.6508 - val_accuracy: 0.3259
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0611 - accuracy: 0.6077
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 424s 946ms/step - loss: 1.0611 - accuracy: 0.6077 - val_loss: 1.5233 - val_accuracy: 0.4226
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0.6577
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 427s 953ms/step - loss: 0.9361 - accuracy: 0.6577 - val_loss: 1.5621 - val_accuracy: 0.4466
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8130 - accuracy: 0.7033
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 430s 959ms/step - loss: 0.8130 - accuracy: 0.7033 - val_loss: 1.5189 - val_accuracy: 0.4810
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.7526
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 513s 1s/step - loss: 0.6983 - accuracy: 0.7526 - val_loss: 2.4134 - val_accuracy: 0.3736
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5933 - accuracy: 0.7934
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 415s 926ms/step - loss: 0.5933 - accuracy: 0.7934 - val_loss: 1.5713 - val_accuracy: 0.4865
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.8224
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 428s 955ms/step - loss: 0.5073 - accuracy: 0.8224 - val_loss: 1.7159 - val_accuracy: 0.4759
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4419 - accuracy: 0.8494
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 406s 905ms/step - loss: 0.4419 - accuracy: 0.8494 - val_loss: 1.8746 - val_accuracy: 0.4365
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3842 - accuracy: 0.8690
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 431s 963ms/step - loss: 0.3842 - accuracy: 0.8690 - val_loss: 1.8652 - val_accuracy: 0.4542
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8848
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 429s 958ms/step - loss: 0.3418 - accuracy: 0.8848 - val_loss: 1.7352 - val_accuracy: 0.4958
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.9015
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 434s 968ms/step - loss: 0.2982 - accuracy: 0.9015 - val_loss: 2.0821 - val_accuracy: 0.4512
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9110
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 432s 963ms/step - loss: 0.2668 - accuracy: 0.9110 - val_loss: 2.0439 - val_accuracy: 0.4519
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9242
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 233s 519ms/step - loss: 0.2367 - accuracy: 0.9242 - val_loss: 2.1514 - val_accuracy: 0.4933

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 10s 85ms/step - loss: 2.1492 - accuracy: 0.4937
# [2.149172067642212, 0.4937308430671692]

# %% [markdown]
# **plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right = 0.95, left=0.0, hspace=0.25, wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right = 0.95, left=0.0, hspace=0.25, wspace=0.35)

# %% [markdown]
# **Saving model**

# %%
model_json = model.to_json()
with open("model_a.json", "w") as json_file:
    json_file.write(model_json)
